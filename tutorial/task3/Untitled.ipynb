# %%
import pandas as pd

# %%
train = pd.read_csv('./data/train.csv', encoding='ms932')
train.head
# Out:
# <bound method NDFrame.head of        datetime   vol            name  temperature  special  curry
# 0    2019-01-06  1385    カレー入りソーセージカツ          7.3        0      1
# 1    2019-01-07  1376          豚肉の生姜焼          9.8        0      0
# 2    2019-01-08  1215          鶏チリソース         10.9        0      0
# 3    2019-01-09   837        手作りロースカツ          5.1        0      0
# 4    2019-01-13  1341     鶏の照り焼きマスタード          5.8        0      0
# ..          ...   ...             ...          ...      ...    ...
# 126  2019-07-09   560            プルコギ         28.8        0      0
# 127  2019-07-10  1309          ポークカレー         33.9        1      1
# 128  2019-07-13   579  鶏のから揚げねぎ塩炒めソース         30.9        0      0
# 129  2019-07-14   436       豚冷シャブ野菜添え         30.3        0      0
# 130  2019-07-15   494          白身魚フライ         30.9        0      0
#
# [131 rows x 6 columns]>

# %%
y = train['vol']
y
# Out:
# 0      1385
# 1      1376
# 2      1215
# 3       837
# 4      1341
#        ...
# 126     560
# 127    1309
# 128     579
# 129     436
# 130     494
# Name: vol, Length: 131, dtype: int64

# %%
X = train[['temperature']]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X.y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-6bfc9f1c36de> in <module>
# ----> 1 model.fit(X.y)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'y'

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.conf_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-8e7521fca4e4> in <module>
# ----> 1 model.conf_
#
# AttributeError: 'LinearRegression' object has no attribute 'conf_'

# %%
model.conf_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-8e7521fca4e4> in <module>
# ----> 1 model.conf_
#
# AttributeError: 'LinearRegression' object has no attribute 'conf_'

# %%
model.coef_
# Out:
# array([-20.4366254])

# %%
model.intercept_
# Out:
# 1220.5943567230104

# %%
test = pd.read_csv('./data/test.csv', encoding='ms932')
test.head()
# Out:
#      datetime  vol       name  temperature  special  curry
# 0  2019-07-16  620      豚すき焼き         30.1        0      0
# 1  2019-07-17  462      エビフライ         25.6        0      0
# 2  2019-07-21  564   チンジャオロース         30.2        0      0
# 3  2019-07-22  622        八宝菜         32.0        0      0
# 4  2019-07-23  707  ジャンボチキンカツ         32.5        0      0

# %%
testX = test[['temperature']] 
pred = model.predict(testX)
pred
# Out:
# array([605.45193216, 697.41674646, 603.40826962, 566.6223439 ,
#        556.4040312 , 533.92374326, 629.97588264, 599.32094454,
#        595.23361946, 556.4040312 , 552.31670612, 552.31670612,
#        519.61810548, 513.48711786, 564.57868136, 585.01530676,
#        558.44769374, 619.75756994, 562.53501882, 540.05473088,
#        540.05473088, 546.1857185 , 544.14205596, 689.2420963 ,
#        685.15477122, 791.42522331, 779.16324807, 707.63505916,
#        742.37732235, 625.88855756, 674.93645852, 679.0237836 ,
#        603.40826962, 748.50830997, 672.89279598, 709.6787217 ,
#        773.03226045, 662.67448328, 632.01954518, 709.6787217 ,
#        728.07168457, 738.28999727, 705.59139662, 713.76604679,
#        701.50407154, 666.76180836, 676.98012106, 646.32518296])

# %%
from sklearn.metrics import mean_absolute_error
y_test = test['vol']

# %%
mae = mean_absolute_error(y_test, pred)
mae
# Out:
# 162.1158425106297

# %%
 train.describe()
# Out:
#                vol  temperature     special       curry
# count   131.000000   131.000000  131.000000  131.000000
# mean    867.992366    17.253435    0.061069    0.099237
# std     270.811700     8.035491    0.240376    0.300127
# min     404.000000     1.200000    0.000000    0.000000
# 25%     637.000000     9.950000    0.000000    0.000000
# 50%     806.000000    18.600000    0.000000    0.000000
# 75%    1070.500000    23.850000    0.000000    0.000000
# max    1417.000000    33.900000    1.000000    1.000000

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['font.family'] = 'meiryo'

# %%
train['vol'].plot()
# Out:
# <AxesSubplot:>
# findfont: Font family ['meiryo'] not found. Falling back to DejaVu Sans.

# %%
train['vol'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:>

# %%
ax = train['vol'].plot(figsize=(12,4), title='お弁当の売上数の推移')
ax.set_xlabel('時間')
ax.set_ylabel('売上数')
# Out:
# Text(0, 0.5, '売上数')
# findfont: Font family ['meiryo'] not found. Falling back to DejaVu Sans.
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12362 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24321 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24403 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22770 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 19978 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 31227 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26178 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 38291 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26178 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 38291 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22770 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 19978 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12362 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24321 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24403 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25512 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 31227 missing from current font.
#   font.set_text(s, 0, flags=flags)
